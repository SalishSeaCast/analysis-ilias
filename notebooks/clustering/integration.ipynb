# %% [markdown]
# # Notebook that integrates and clusters individual days

# %% [markdown]
# ## Importing

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn_som.som import SOM
import salishsea_tools.viz_tools as sa_vi
from sklearn import preprocessing

# %% [markdown]
# ## Datasets Preparation

# %%
def datasets_preparation ():
    
    temp_i1 = (ds.votemper.where(mask==1)[0,0:15] * ds.e3t.where(mask==1)
        [0,0:15]).sum('deptht', skipna = True, min_count = 15) / mesh.gdepw_0[0,15]

    temp_i2 = (ds.votemper.where(mask==1)[0,15:27] * ds.e3t.where(mask==1)
        [0,15:27]).sum('deptht', skipna = True, min_count = 12) / (mesh.gdepw_0[0,27] - mesh.gdepw_0[0,14])

    saline_i1 = (ds.vosaline.where(mask==1)[0,0:15] * ds.e3t.where(mask==1)
        [0,0:15]).sum('deptht', skipna = True, min_count = 15) / mesh.gdepw_0[0,15]

    saline_i2 = (ds.vosaline.where(mask==1)[0,15:27] * ds.e3t.where(mask==1)
        [0,15:27]).sum('deptht', skipna = True, min_count = 12) / (mesh.gdepw_0[0,27] - mesh.gdepw_0[0,14])

    sil_i = (ds_bio.silicon.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    nitr_i = (ds_bio.nitrate.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    ammo_i = (ds_bio.ammonium.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    diat_i = (ds_bio.diatoms.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    flag_i = (ds_bio.flagellates.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]
    
    micro_i = (ds_bio.microzooplankton.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    meso_i = (ds_bio.mesozooplankton.where(mask==1)[0,0:27] * ds.e3t.where(mask==1)
        [0,0:27]).sum('deptht', skipna = True, min_count = 27) / mesh.gdepw_0[0,27]

    return (temp_i1, temp_i2, saline_i1, saline_i2, sil_i, nitr_i, ammo_i, diat_i,  flag_i, micro_i, meso_i)

# %% [markdown]
# ## SOM

# %%
def som (inputs, m, n):

    # Pre processing     
    indx = np.where(~np.isnan(inputs).any(axis=0))
    inputs2 = inputs[:,indx[0]]
    inputs3 = preprocessing.normalize(inputs2, norm= 'max')
    inputs3 = inputs3.transpose()

    # SOM
    temp_som = SOM(m, n, dim= inputs3[0,:].size, lr = 0.1)
    temp_som.fit(inputs3, epochs = 5)
    predictions = temp_som.predict(inputs3)

    # Post processing
    unique, counts = np.unique(predictions, return_counts=True)
    indx2 = np.full(inputs[0,:].size,np.nan)
    indx2[indx[0]] = predictions
    clusters = np.reshape(indx2,(898,398)) 

    # Preparation of the dataarray 
    clusters= xr.DataArray(clusters,
        coords = {'y': temp_i1.y, 'x': temp_i1.x},
        dims = ['y','x'],
        attrs=dict(description="Clusters of the performed self organizing map algorithm",
        long_name ="Cluster",
        units="count"),)
    
    return (clusters, unique, counts)

# %% [markdown]
# ## Printing

# %%
def printing ():

    print('Date: ' + str(date.date[0]), '\n'*2)
    
    for i in unique:

        print('The amount of grid boxes for cluster ' + str(i), ' is ' + str(counts[i]),'\n')

        print('The minimum temperature for cluster '+ str(i), ' is ' + str(np.round(xr.concat([temp_i1.where(clusters==i),temp_i2.where(clusters==i)], 'y').min().values,2)), ' degrees_C m')
        print('The maximum temperature for cluster '+ str(i), ' is ' + str(np.round(xr.concat([temp_i1.where(clusters==i),temp_i2.where(clusters==i)], 'y').max().values,2)), ' degrees_C m')
        print('The mean temperature for cluster '+ str(i), ' is ' + str(np.round(xr.concat([temp_i1.where(clusters==i),temp_i2.where(clusters==i)], 'y').mean().values,2)), ' degrees_C m', '\n')

        print('The minimum salinity for cluster '+ str(i), ' is ' + str(np.round(xr.concat([saline_i1.where(clusters==i),saline_i2.where(clusters==i)], 'y').min().values,2)), ' g kg-1 m')
        print('The maximum salinity for cluster '+ str(i), ' is ' + str(np.round(xr.concat([saline_i1.where(clusters==i),saline_i2.where(clusters==i)], 'y').max().values,2)), ' g kg-1 m')
        print('The mean salinity for cluster '+ str(i), ' is ' + str(np.round(xr.concat([saline_i1.where(clusters==i),saline_i2.where(clusters==i)], 'y').mean().values,2)), ' g kg-1 m', '\n'*2)
        
    
        print('The minimum silicon concentration for cluster '+ str(i), ' is ' + str(np.round(sil_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum silicon concentration for cluster '+ str(i), ' is ' + str(np.round(sil_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean silicon concentration for cluster '+ str(i), ' is ' + str(np.round(sil_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n')

        print('The minimum nitrate concentration for cluster '+ str(i), ' is ' + str(np.round(nitr_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum nitrate concentration for cluster '+ str(i), ' is ' + str(np.round(nitr_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean nitrate concentration for cluster '+ str(i), ' is ' + str(np.round(nitr_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n')

        print('The minimum ammonium concentration for cluster '+ str(i), ' is ' + str(np.round(ammo_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum ammonium concentration for cluster '+ str(i), ' is ' + str(np.round(ammo_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean ammonium concentration for cluster '+ str(i), ' is ' + str(np.round(ammo_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n'*2)


        print('The minimum diatom concentration for cluster '+ str(i), ' is ' + str(np.round(diat_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum diatom concentration for cluster '+ str(i), ' is ' + str(np.round(diat_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean diatom concentration for cluster '+ str(i), ' is ' + str(np.round(diat_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n')

        print('The minimum flagellate concentration for cluster '+ str(i), ' is ' + str(np.round(flag_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum flagellate concentration for cluster '+ str(i), ' is ' + str(np.round(flag_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean flagellate concentration for cluster '+ str(i), ' is ' + str(np.round(flag_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n'*2)


        print('The minimum microzooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(micro_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum microzooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(micro_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean microzooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(micro_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n')

        print('The minimum mesozooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(meso_i.where(clusters==i).min().values,2)), ' mmol m-3')
        print('The maximum mesozooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(meso_i.where(clusters==i).max().values,2)), ' mmol m-3')
        print('The mean mesozooplankton concentration for cluster '+ str(i), ' is ' + str(np.round(meso_i.where(clusters==i).mean().values,2)), ' mmol m-3', '\n'*2)

# %% [markdown]
# ## Plotting

# %%
def plotting (labels, titles, variables):

    fig, ax = plt.subplots(2,2, figsize=(10, 15))

    if variables[0].all() == clusters.all():

        cmap = plt.get_cmap('tab20', unique.max()+1)
        cmap.set_bad('gray')
        clus = variables[0].plot(ax=ax[0,0], cmap=cmap, vmin = unique.min(), vmax = unique.max()+1, add_colorbar=False)

        cbar = fig.colorbar(clus, ticks = unique+0.5) 
        cbar.set_ticklabels(unique)
        cbar.set_label(labels[0])

    else:
        
        cmap = plt.get_cmap('cubehelix')
        cmap.set_bad('gray')
        variables[0].plot(ax=ax[0,0], cmap=cmap, cbar_kwargs={'label': labels[0]})

    plt.subplots_adjust(left=0.1,
        bottom=0.1, 
        right=0.9, 
        top=0.95, 
        wspace=0.15, 
        hspace=0.15)
        
    cmap = plt.get_cmap('cubehelix')
    cmap.set_bad('gray')

    variables[1].plot(ax=ax[0,1], cmap=cmap, cbar_kwargs={'label': labels[1]})
    variables[2].plot(ax=ax[1,0], cmap=cmap, cbar_kwargs={'label': labels[2]})

    sa_vi.set_aspect(ax[0,0])
    sa_vi.set_aspect(ax[0,1])
    sa_vi.set_aspect(ax[1,0])

    ax[0,0].title.set_text(titles[0])
    ax[0,1].title.set_text(titles[1])
    ax[1,0].title.set_text(titles[2])

    if len(titles) == 3:

        ax[1,1].axis('off')
    
    else:

        variables[3].plot(ax=ax[1,1], cmap=cmap, cbar_kwargs={'label': labels[3]})
        sa_vi.set_aspect(ax[1,1])
        ax[1,1].title.set_text(titles[3])

    fig.suptitle(str(date.date[0]))

# %% [markdown]
# ## Main Body

# %%
# Dataset and date
ds = xr.open_dataset ('/results2/SalishSea/nowcast-green.202111/31mar22/SalishSea_1d_20220331_20220331_grid_T.nc')
ds_bio = xr. open_dataset ('/results2/SalishSea/nowcast-green.202111/31mar22/SalishSea_1d_20220331_20220331_biol_T.nc')
date = pd.DatetimeIndex(ds['time_counter'].values)

# Open the mesh mask
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask202108.nc')
mask = mesh.tmask.to_numpy()

temp_i1, temp_i2, saline_i1, saline_i2, sil_i, nitr_i, ammo_i, diat_i, flag_i, micro_i, meso_i = datasets_preparation()

# Potential input variables
drivers = np.stack([np.ravel(temp_i1), np.ravel(temp_i2), np.ravel(saline_i1), np.ravel(saline_i2)])
nutrients = np.stack([np.ravel(sil_i), np.ravel(nitr_i), np.ravel(ammo_i)])
phyto = np.stack([np.ravel(diat_i), np.ravel(flag_i)])
zoo = np.stack([np.ravel(micro_i), np.ravel(meso_i)])

# Dimensions of the map
m = 3
n = 2

clusters, unique, counts = som(drivers, m, n)

printing()

# Drivers
labels = ['Conservative Temperature [degree_C m]', 
            'Conservative Temperature [degree_C m]', 'Reference Salinity [g kg-1 m]',
            'Reference Salinity [g kg-1 m]']
titles = ['Conservative Temperature (0m - 15m)',
            'Conservative Temperature (15m - 100m)', 'Reference Salinity (0m - 15m)',
            'Reference Salinity (15m - 100m)']
variables = [temp_i1, temp_i2, saline_i1, saline_i2]
plotting (labels, titles, variables)

# Nutrients
labels = ['Clusters [count]', 'Silicon Concentration [mmol m-2]',
            'Nitrate Concentration [mmol m-2]', 'Ammonium Concentration [mmol m-2]']
titles = ['Clusters', 'Silicon', 'Nitrate', 'Ammonium']
variables = [clusters, sil_i, nitr_i, ammo_i]
plotting (labels, titles, variables)

# Phytoplankton
labels = ['Clusters [count]', 'Diatoms Concentration [mmol m-2]',
            'Flagellates Concentration [mmol m-2]']
titles = ['Clusters', 'Diatoms', 'Flagellates']
variables = [clusters, diat_i, flag_i]
plotting (labels, titles, variables)

# Zooplankton
labels = ['Clusters [count]', 'Microzooplankton Concentration [mmol m-2]',
            'Mesozooplankton Concentration [mmol m-2]']
titles = ['Clusters', 'Microzooplankton', 'Mesozooplankton']
variables = [clusters, micro_i, meso_i]
plotting (labels, titles, variables)
# Out:
# Date: 2022-03-31
#
#
# The amount of grid boxes for cluster 0  is 8343
#
# The minimum temperature for cluster 0  is 7.84  degrees_C m
# The maximum temperature for cluster 0  is 10.22  degrees_C m
# The mean temperature for cluster 0  is 8.59  degrees_C m
#
# The minimum salinity for cluster 0  is 22.48  g kg-1 m
# The maximum salinity for cluster 0  is 29.86  g kg-1 m
# The mean salinity for cluster 0  is 27.97  g kg-1 m
#
#
# The minimum silicon concentration for cluster 0  is 39.57  mmol m-3
# The maximum silicon concentration for cluster 0  is 58.17  mmol m-3
# The mean silicon concentration for cluster 0  is 46.39  mmol m-3
#
# The minimum nitrate concentration for cluster 0  is 18.87  mmol m-3
# The maximum nitrate concentration for cluster 0  is 31.03  mmol m-3
# The mean nitrate concentration for cluster 0  is 24.36  mmol m-3
#
# The minimum ammonium concentration for cluster 0  is 0.95  mmol m-3
# The maximum ammonium concentration for cluster 0  is 1.99  mmol m-3
# The mean ammonium concentration for cluster 0  is 1.24  mmol m-3
#
#
# The minimum diatom concentration for cluster 0  is 0.13  mmol m-3
# The maximum diatom concentration for cluster 0  is 0.68  mmol m-3
# The mean diatom concentration for cluster 0  is 0.35  mmol m-3
#
# The minimum flagellate concentration for cluster 0  is 0.05  mmol m-3
# The maximum flagellate concentration for cluster 0  is 0.12  mmol m-3
# The mean flagellate concentration for cluster 0  is 0.08  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 0  is 0.07  mmol m-3
# The maximum microzooplankton concentration for cluster 0  is 0.39  mmol m-3
# The mean microzooplankton concentration for cluster 0  is 0.16  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 0  is 0.14  mmol m-3
# The maximum mesozooplankton concentration for cluster 0  is 0.53  mmol m-3
# The mean mesozooplankton concentration for cluster 0  is 0.29  mmol m-3
#
#
# The amount of grid boxes for cluster 1  is 15782
#
# The minimum temperature for cluster 1  is 6.86  degrees_C m
# The maximum temperature for cluster 1  is 9.47  degrees_C m
# The mean temperature for cluster 1  is 8.28  degrees_C m
#
# The minimum salinity for cluster 1  is 26.2  g kg-1 m
# The maximum salinity for cluster 1  is 30.01  g kg-1 m
# The mean salinity for cluster 1  is 28.75  g kg-1 m
#
#
# The minimum silicon concentration for cluster 1  is 44.07  mmol m-3
# The maximum silicon concentration for cluster 1  is 57.42  mmol m-3
# The mean silicon concentration for cluster 1  is 49.22  mmol m-3
#
# The minimum nitrate concentration for cluster 1  is 23.68  mmol m-3
# The maximum nitrate concentration for cluster 1  is 28.07  mmol m-3
# The mean nitrate concentration for cluster 1  is 25.31  mmol m-3
#
# The minimum ammonium concentration for cluster 1  is 0.83  mmol m-3
# The maximum ammonium concentration for cluster 1  is 1.28  mmol m-3
# The mean ammonium concentration for cluster 1  is 1.08  mmol m-3
#
#
# The minimum diatom concentration for cluster 1  is 0.14  mmol m-3
# The maximum diatom concentration for cluster 1  is 0.49  mmol m-3
# The mean diatom concentration for cluster 1  is 0.28  mmol m-3
#
# The minimum flagellate concentration for cluster 1  is 0.05  mmol m-3
# The maximum flagellate concentration for cluster 1  is 0.12  mmol m-3
# The mean flagellate concentration for cluster 1  is 0.08  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 1  is 0.07  mmol m-3
# The maximum microzooplankton concentration for cluster 1  is 0.24  mmol m-3
# The mean microzooplankton concentration for cluster 1  is 0.15  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 1  is 0.15  mmol m-3
# The maximum mesozooplankton concentration for cluster 1  is 0.38  mmol m-3
# The mean mesozooplankton concentration for cluster 1  is 0.24  mmol m-3
#
#
# The amount of grid boxes for cluster 2  is 6916
#
# The minimum temperature for cluster 2  is 7.55  degrees_C m
# The maximum temperature for cluster 2  is 8.81  degrees_C m
# The mean temperature for cluster 2  is 8.16  degrees_C m
#
# The minimum salinity for cluster 2  is 25.27  g kg-1 m
# The maximum salinity for cluster 2  is 29.61  g kg-1 m
# The mean salinity for cluster 2  is 28.36  g kg-1 m
#
#
# The minimum silicon concentration for cluster 2  is 37.4  mmol m-3
# The maximum silicon concentration for cluster 2  is 50.22  mmol m-3
# The mean silicon concentration for cluster 2  is 43.26  mmol m-3
#
# The minimum nitrate concentration for cluster 2  is 19.12  mmol m-3
# The maximum nitrate concentration for cluster 2  is 25.27  mmol m-3
# The mean nitrate concentration for cluster 2  is 23.38  mmol m-3
#
# The minimum ammonium concentration for cluster 2  is 1.01  mmol m-3
# The maximum ammonium concentration for cluster 2  is 1.84  mmol m-3
# The mean ammonium concentration for cluster 2  is 1.27  mmol m-3
#
#
# The minimum diatom concentration for cluster 2  is 0.22  mmol m-3
# The maximum diatom concentration for cluster 2  is 0.63  mmol m-3
# The mean diatom concentration for cluster 2  is 0.41  mmol m-3
#
# The minimum flagellate concentration for cluster 2  is 0.07  mmol m-3
# The maximum flagellate concentration for cluster 2  is 0.12  mmol m-3
# The mean flagellate concentration for cluster 2  is 0.1  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 2  is 0.1  mmol m-3
# The maximum microzooplankton concentration for cluster 2  is 0.41  mmol m-3
# The mean microzooplankton concentration for cluster 2  is 0.21  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 2  is 0.2  mmol m-3
# The maximum mesozooplankton concentration for cluster 2  is 0.53  mmol m-3
# The mean mesozooplankton concentration for cluster 2  is 0.33  mmol m-3
#
#
# The amount of grid boxes for cluster 3  is 1595
#
# The minimum temperature for cluster 3  is 6.79  degrees_C m
# The maximum temperature for cluster 3  is 8.76  degrees_C m
# The mean temperature for cluster 3  is 7.97  degrees_C m
#
# The minimum salinity for cluster 3  is 28.13  g kg-1 m
# The maximum salinity for cluster 3  is 29.98  g kg-1 m
# The mean salinity for cluster 3  is 29.12  g kg-1 m
#
#
# The minimum silicon concentration for cluster 3  is 37.78  mmol m-3
# The maximum silicon concentration for cluster 3  is 53.41  mmol m-3
# The mean silicon concentration for cluster 3  is 41.34  mmol m-3
#
# The minimum nitrate concentration for cluster 3  is 20.03  mmol m-3
# The maximum nitrate concentration for cluster 3  is 25.6  mmol m-3
# The mean nitrate concentration for cluster 3  is 22.58  mmol m-3
#
# The minimum ammonium concentration for cluster 3  is 0.82  mmol m-3
# The maximum ammonium concentration for cluster 3  is 1.53  mmol m-3
# The mean ammonium concentration for cluster 3  is 1.31  mmol m-3
#
#
# The minimum diatom concentration for cluster 3  is 0.22  mmol m-3
# The maximum diatom concentration for cluster 3  is 0.63  mmol m-3
# The mean diatom concentration for cluster 3  is 0.42  mmol m-3
#
# The minimum flagellate concentration for cluster 3  is 0.06  mmol m-3
# The maximum flagellate concentration for cluster 3  is 0.14  mmol m-3
# The mean flagellate concentration for cluster 3  is 0.11  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 3  is 0.07  mmol m-3
# The maximum microzooplankton concentration for cluster 3  is 0.4  mmol m-3
# The mean microzooplankton concentration for cluster 3  is 0.28  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 3  is 0.19  mmol m-3
# The maximum mesozooplankton concentration for cluster 3  is 0.52  mmol m-3
# The mean mesozooplankton concentration for cluster 3  is 0.36  mmol m-3
#
#
# The amount of grid boxes for cluster 4  is 2178
#
# The minimum temperature for cluster 4  is 7.32  degrees_C m
# The maximum temperature for cluster 4  is 8.19  degrees_C m
# The mean temperature for cluster 4  is 7.8  degrees_C m
#
# The minimum salinity for cluster 4  is 28.85  g kg-1 m
# The maximum salinity for cluster 4  is 30.43  g kg-1 m
# The mean salinity for cluster 4  is 29.66  g kg-1 m
#
#
# The minimum silicon concentration for cluster 4  is 38.03  mmol m-3
# The maximum silicon concentration for cluster 4  is 48.91  mmol m-3
# The mean silicon concentration for cluster 4  is 41.23  mmol m-3
#
# The minimum nitrate concentration for cluster 4  is 20.81  mmol m-3
# The maximum nitrate concentration for cluster 4  is 24.61  mmol m-3
# The mean nitrate concentration for cluster 4  is 22.86  mmol m-3
#
# The minimum ammonium concentration for cluster 4  is 0.63  mmol m-3
# The maximum ammonium concentration for cluster 4  is 1.42  mmol m-3
# The mean ammonium concentration for cluster 4  is 1.15  mmol m-3
#
#
# The minimum diatom concentration for cluster 4  is 0.24  mmol m-3
# The maximum diatom concentration for cluster 4  is 0.5  mmol m-3
# The mean diatom concentration for cluster 4  is 0.36  mmol m-3
#
# The minimum flagellate concentration for cluster 4  is 0.09  mmol m-3
# The maximum flagellate concentration for cluster 4  is 0.16  mmol m-3
# The mean flagellate concentration for cluster 4  is 0.12  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 4  is 0.09  mmol m-3
# The maximum microzooplankton concentration for cluster 4  is 0.37  mmol m-3
# The mean microzooplankton concentration for cluster 4  is 0.24  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 4  is 0.19  mmol m-3
# The maximum mesozooplankton concentration for cluster 4  is 0.44  mmol m-3
# The mean mesozooplankton concentration for cluster 4  is 0.31  mmol m-3
#
#
# The amount of grid boxes for cluster 5  is 11665
#
# The minimum temperature for cluster 5  is 7.06  degrees_C m
# The maximum temperature for cluster 5  is 8.23  degrees_C m
# The mean temperature for cluster 5  is 7.64  degrees_C m
#
# The minimum salinity for cluster 5  is 29.62  g kg-1 m
# The maximum salinity for cluster 5  is 32.53  g kg-1 m
# The mean salinity for cluster 5  is 31.11  g kg-1 m
#
#
# The minimum silicon concentration for cluster 5  is 35.28  mmol m-3
# The maximum silicon concentration for cluster 5  is 43.02  mmol m-3
# The mean silicon concentration for cluster 5  is 38.9  mmol m-3
#
# The minimum nitrate concentration for cluster 5  is 21.23  mmol m-3
# The maximum nitrate concentration for cluster 5  is 25.48  mmol m-3
# The mean nitrate concentration for cluster 5  is 24.16  mmol m-3
#
# The minimum ammonium concentration for cluster 5  is 0.26  mmol m-3
# The maximum ammonium concentration for cluster 5  is 1.26  mmol m-3
# The mean ammonium concentration for cluster 5  is 0.83  mmol m-3
#
#
# The minimum diatom concentration for cluster 5  is 0.08  mmol m-3
# The maximum diatom concentration for cluster 5  is 0.49  mmol m-3
# The mean diatom concentration for cluster 5  is 0.27  mmol m-3
#
# The minimum flagellate concentration for cluster 5  is 0.05  mmol m-3
# The maximum flagellate concentration for cluster 5  is 0.18  mmol m-3
# The mean flagellate concentration for cluster 5  is 0.1  mmol m-3
#
#
# The minimum microzooplankton concentration for cluster 5  is 0.04  mmol m-3
# The maximum microzooplankton concentration for cluster 5  is 0.32  mmol m-3
# The mean microzooplankton concentration for cluster 5  is 0.18  mmol m-3
#
# The minimum mesozooplankton concentration for cluster 5  is 0.08  mmol m-3
# The maximum mesozooplankton concentration for cluster 5  is 0.41  mmol m-3
# The mean mesozooplankton concentration for cluster 5  is 0.24  mmol m-3
