# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
from tqdm import tqdm

# %%
# two sum

nums = [3,3]

target = 6

hashmap = {}
for i in range(len(nums)):
    complement = target - nums[i]
    if complement in hashmap:
        print([i, hashmap[complement]])
    hashmap[nums[i]] = i
# Return an empty list if no solution is found
print('[]')
# Out:
# [1, 0]
# []

# %%
# 3Sum
nums = [0, -1, 2, -3, 1]

ans = []
target = -1

for i in range (len(nums)-2):
    for j in range (i+1, len(nums)-1):
        for k in range (j+1, len(nums)):
            
            if nums[i] + nums[j] + nums[k] == target:
                ans.append([i, j, k])

print(ans)

hashmap = {}
ans = []
target = -1

for j in range (len(nums)):

    for k in range(j+1,len(nums)):

        val = target - (nums[k] + nums[j])

        if val in hashmap:
            
            ans.append([hashmap[val],j,k])
    
    # Storing it for potential use
    if nums[j] not in hashmap:
            hashmap[nums[j]] = j
         
print(ans)
# Out:
# [[0, 2, 3]]

# %%
# Container

nums = [2, 1, 8, 6, 4, 6, 5, 5]

res = 0
for i in range (len(nums)):
    for j in range (i+1, len(nums)):

        water = min(nums[i], nums[j]) * (j-i)

        res = max(res,water)

print (res)


res = 0
left = 0
right = len(nums)-1

while left < right:

    water = min(nums[left], nums[right]) * (right - left)

    res = max(res, water)

    if nums[left] < nums[right]:
        left += 1
    else:
        right -= 1

print(res)
# Out:
# 25
# 25

# %%
# product of array except self

nums = [2,1,3,4]

product_l = [1]*len(nums) # left_side product
product_r = [1]*len(nums) # right product
product_f = [1]*len(nums) # final product

for i in range (1, len(nums)): # left product loop

    product_l[i] = product_l[i-1] * nums[i-1]

for i in range (len(nums)-2,-1,-1): # right product loop, going backwards

    product_r[i] = product_r[i+1] * nums[i+1]

for i in range (0, len(nums)):
    product_f[i] = product_l[i] * product_r[i]

print(product_f)
# Out:
# [12, 24, 8, 6]

# %%
# maximum subarray

nums = [-2,1,-3,4,-1,2,1,-5,4]

sum_new = nums[0]
sum_old = sum_new

for i in range (1, len(nums)):

    if sum_old + nums[i] > nums[i]:
        sum_old = sum_old + nums[i]
        
    else:
        sum_old = nums[i]
    
    if sum_old > sum_new:
        sum_new = sum_old

print(max(sum_new,sum_old))
# Out:
# 6

# %%
# maximum subarray (product)

nums = [-4,-3,-2]

currMax = nums[0] # max product at the current end
currMin = nums[0] # min product at the current end
maxProd = nums[0] # overall max product

for i in range (1, len(nums)):

    temp = max(nums[i], currMax*nums[i], currMin*nums[i])
    currMin = min(nums[i], currMax*nums[i], currMin*nums[i])

    currMax = temp

    if maxProd < currMax:
        maxProd = currMax

print(maxProd)
# Out:
# 12

# %%
# Maximum rotated sorted array

nums = [11,13,15,17]

low = 0
high = len(nums)-1

while low < high:

    if nums[low] < nums[high]:
        print (nums[high])
        break
    
    med = (low + high) // 2

    if nums[med] < nums[high]:
        high = med - 1

    else:
        low = med

print (nums[high])
# Out:
# 17
# 17

# %%
# Search in Rotated sorted array

nums = [4,5,6,7,0,1,2]
target = 0

low = 0
high = len(nums)-1

while low <= high:
        
    med = (low + high) // 2

    if nums[med] == target:
        print(med)

    if nums[low] <= nums[med]:
        if nums[med] > target and nums[low] <= target:
            high = med -1

        else:
            low = med +1

    else:
        if nums[high] >= target and nums[med] < target:
            low = med +1
        
        else:
            high = med - 1
# Out:
# 4

# %%
# youtube video

s = 'dsahjpjauf'
words = ['ahjpjauf', 'ja', 'ahbwzgqnuk', 'tnmlanowax']

out = 0
for word in words:

    indx = -1
    chars = 0
    for c in word:
        
        if c in s[indx+1:]: # found character in s
            indx = s.index(c,indx+1,len(s))
            chars += 1
        
    if chars == len(word): # all characters where found properly
        out = out + 1

print(out)
# Out:
# 2

# %%
# string reverse

rev = ''
for i in range (len(s)-1,-1,-1):
    rev += s[i]

# %%
# longest common subsequence

s1 = 'ABX'
s2 = 'ACX'

lon1 = 0
indx1 = -1

for c1 in s1:

    if c1 in s2[indx1+1:]:
        indx1 = s2.index(c1,indx1+1,len(s2))
        lon1 = lon1 + 1

lon2 = 0
indx2 = -1

for c2 in s2:

    if c2 in s1[indx2+1:]:
        indx2 = s1.index(c2,indx2+1,len(s1))
        lon2 = lon2 + 1

print(max(lon1,lon2))
# Out:
# 2

# %%
# Palindrome

s = ''
s = s.lower()
s = ''.join(c for c in s if c.isalnum())

s2 = ''.join(s[c] for c in range(len(s)-1,-1,-1))

if s==s2:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
# regular expression matching

s = 'aa'
p = 'a*'

indx = -1
flag = True


for i in p:
    if (i != '.') & (i !='*'):
        if i in s[indx+1:]:
            indx = s.index(i,indx+1,len(s))
        else:
            flag = False

print (flag)

for i in range(len(p)):
    if p[i] == '*':
        print(p[i-1])
# Out:
# True
# a

# %%
## Common slot for meeting of two persons

slt1 = [[10,50], [60,120], [140,210]]
slt2 = [[10,15], [60,70]]

d = 2

dist1 = [x[0] for x in slt1 if x[1] -x[0] -d >0] # valid durations
dist2 = [x[0] for x in slt2 if x[1] -x[0] -d >0]

com_d = [x for x in dist1 if x in dist2] # common starting points (indexes, based on start1)

if com_d != []:
    print([com_d[0], com_d[0]+d])
else:
    print (com_d)
# Out:
# [10, 12]

# %%
## Islands

grid= [['L', 'L', 'W', 'W', 'W'],
    ['W', 'L', 'W', 'W', 'L'],
    ['L', 'W', 'W', 'L', 'L'],
    ['W', 'W', 'W', 'W', 'W'],
    ['L', 'W', 'L', 'L', 'W']]

len(grid[0])
# Out:
# 5

# %%
coords = []
dist = []

for i in range (len(grid)):
    
    for j in range (len(grid[i])):

        if grid[i][j] == 'L':
            coords.append([i,j])
            dist.append((i**2+j**2)**0.5)

# %%
# smallest missing positive number

nums = [8, 2, 4, 5, 3, 7, 1]

hashmap = [0]*(len(nums)+2) # one extra element, one because we start at zero

for i in range (len(nums)):
    hashmap[nums[i]] += 1

for i in range (1, len(hashmap)):
    if hashmap[i] == 0:
        print(i)
# Out:
# 0
# 6

# %%
# hacker rank

s = str(input())

con = s[0]
num = 1

for i in range (1,len(s)):
    
    if con == s[i]:
        num += 1
    
    else: # another character
        print(num, con)
        num = 1 # for the new character
        con = s[i] # the new character
        
print(num, con)
# Out:
# 1 1
# 3 2
# 1 3
# 2 1

# %%
# Contains duplicate

seen = set()
for num in nums:
    if num in seen:
        flag = True
    seen.add(num)
flag = False

# %%
# Hacker rank - logo

s = input()

letters = [0]*3
sort = [0]*3
indx = 0 # index of the final lists

count = 1
c = s[0]

for i in range (1, len(s)):
    
    if c == s[i]:
        count += 1
        
    else:
        if indx < 3: # have not found 3 elements
    
            sort[indx] = count
            letters[indx] = c
            indx += 1
        
        else: # have 3 elements already
            
            if count > sort[indx-1]: # we need to change
                
                sort[indx-1] = count
                letters[indx-1] = c
                
        
        count = 1
        c = s[i]

test = list(zip(letters,sort))
test.sort(key=lambda x: (-x[1], x[0]))
print(test)
# Out:
# [('b', 3), ('c', 2), ('z', 2)]

# %%
def cube ():

    n = int(input())

    b = []
    for i in range (n):
        b.append(int(input()))

    temp = list(b)
    o = 'Yes'

    while (o =='Yes') & (len(temp) > 0):

        if (max(temp) != temp[0]) & (max(temp) != temp[-1]):
            o = 'No'
            break

        elif max(temp) == temp[0]:
            temp.pop(0)
        

        elif max(temp) == temp[-1]:
            temp.pop(-1)


    print(o)

# %%
t = int(input())
for i in range (t):
    cube()
# Out:
# Yes
# No

# %%
    vowels = 'AEIOU'
    
    kevin = sum([len(string) - i for i in range(len(string)) if string[i] in vowels])
    stuart = sum([len(string) - i for i in range(len(string)) if string[i] not in vowels])
    
    print('Draw' if kevin == stuart
        else f'Kevin {kevin}' if kevin > stuart
        else f'Stuart {stuart}')

# %%
string = 'AABCAAADA'
k = 3

length = len(string)//k

for i in range(length):
    substring = string[k*i:k*(i+1)]
    for s in range(len(substring)):

        final_string = ''
        if s == 0:
            final_string += (substring[s])
        else:
            if substring[s] not in test:
                final_string = test.join(substring[s])
    print(test)

# %%
test = datetime.datetime.fromisoformat('2012-11-01T04:16:13-04:00')
test2 = datetime.datetime.fromisoformat('2012-11-01T04:16:13-05:00')

# %%
import math
AB = float(input())
BC = float(input())
MC = math.sqrt(AB**2 + BC**2) / 2
sine = MC / BC

# %%
math.degrees(math.asin(sine))

# %%
n, m = (map(int, input().split()))

array = []
for i in range(n):
    array.append(int(input()))
A = []
B = []

for i in range (m):
    A.append(int(input()))
    
for i in range (m):
    B.append(int(input()))
    
happiness = 0
for i in array:
    if i in A:
        happiness += 1
    
    elif i in B:
        happiness -= 1

# %%
n = int(input())
words = []
unique_words = []
counts = []

words = [input() for i in range(n)]

    
for word in words:
    if word not in unique_words:
        unique_words.append(word)
        counts.append(words.count(word))

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
 
model_id = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
input_ids = tokenizer("jjjj, world!", return_tensors="pt")
with torch.no_grad():
    outputs = model(**input_ids)
output_tokens = outputs.logits.argmax(dim=-1)
output_text = tokenizer.decode(output_tokens[0], skip_special_tokens=False)
print(output_text)

# %%
from transformers import pipeline
 
model_id = "distilbert-base-uncased-finetuned-sst-2-english"
classifier = pipeline("sentiment-analysis", model=model_id)
result = classifier("Machine Learning Mastery is a bad website for learning machine learning.")
print(result)

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
import random
import gymnasium as gym
import numpy as np

# %%
environment = gym.make("FrozenLake-v1", is_slippery=False, render_mode="ansi")
environment.reset()
print(environment.render())

# %%
# Our table has the following dimensions:
# (rows x columns) = (states x actions) = (16 x 4)
qtable = np.zeros((16, 4))

# Alternatively, the gym library can also directly g
# give us the number of states and actions using 
# "env.observation_space.n" and "env.action_space.n"
nb_states = environment.observation_space.n  # = 16
nb_actions = environment.action_space.n      # = 4
qtable = np.zeros((nb_states, nb_actions))

# Let's see how it looks
print('Q-table =')
print(qtable)

# %%
environment.step(2)
print(environment.render())

# %%
action = environment.action_space.sample()

# 2. Implement this action and move the agent in the desired direction
new_state, reward, done, info, _ = environment.step(action)

# Display the results (reward and map)
print(environment.render())
print(f'Reward = {reward}')

# %%
Str = "Python is a powerful and versatile programming language"
words = Str.split()

# %%
test = ['00000001 0 255.' '00000001 0 255.']

# %%
for i in test:
    parts= i.split('.')

parts = parts[:-1]

for i in parts:
    parts2=i.split(' ')

    analog = (bin(int(parts2[0])) // 255) * (int(parts2[2]) - int(parts2[1])) + int(parts2[1])

    analog = round(analog,1)

# %%
bin(int(parts2[0]))

# %%
parts2[0] / 4

# %%
print('')

# %%
parts2

# %%
analog

# %%
parts2

# %%
parts2

# %%
parts = test[0].split('.')

# %%
parts

# %%
parts2 = parts[0].split(' ')

# %%
parts2

# %%
parts[0]

# %%
    for parts in toParse:
        
        analog = (int(parts[0]) // 255) * (int(parts[2]) - int(parts[1])) + int(parts[1])
        analog = round(analog,1)

# %%
words[0][:-2]

# %%
Str.split()

# %%
test1 = 'love'
test2 = 'hate'

# %%
for i in range(0, len(test1)):
    print(ord(test1[i]) - ord(test2[i]))

# %%
test = [ord(c) + 4 for c in Str]

# %%
test2 = ''.join(chr(i) for i in test)

# %%
test2

# %%
for i in Str.split():
    print(len(i))

# %%
for episode in range(episodes):
    state = env.reset()
    done = False
 
    for _ in range(max_steps):
        # Choose action (epsilon-greedy strategy)
        if np.random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(Q[state[0], :])
        
        # Perform action and observe the outcome
        next_state, reward, done, _ , _ = env.step(action)
        
        # Update Q-value using the Bellman equation
        Q [state[0], action] = Q [state[0], action] + learning_rate * (reward + discount_factor * np.max(Q [next_state,:]) - Q [state[0], action])
        
        # Transition to next state
        state = (next_state, 0)
        
        # If the episode is finished, break the loop
        if done:
            break

# %%
state = env.reset()
done = False
total_reward = 0
 
while not done:
    action = np.argmax(Q[state[0], :])
    next_state, reward, done, _, _ = env.step(action)
    total_reward += reward
    state = (next_state, 0)
    env.render()

# %%
# Seasonalities

vars = list(file.data_vars.keys())

names_new = ['DB', 'NB', 'DPR', 'NPR']

names_long = ['Diatom biomass', 'Nanoflagellate biomass', 'Diatom production rate', 'Nanoflagellate production rate']

units = ['mmol N m-2', 'mmol N m-2', 's-1', 's-1']

levels = ['0-100 m depth integrated', '0-100 m depth integrated', '0-100 m depth integrated', '0-100 m depth integrated']

indx = []
indx.append(vars.index('Diatom'))
indx.append(vars.index('Flagellate'))
indx.append(vars.index('Diatom_Production_Rate'))
indx.append(vars.index('Flagellate_Production_Rate'))

coords = dict(time_counter=file.time_counter, y=file.y, x=file.x)

# %%
vars = list(file.data_vars.keys())

names_new = ['SWR', 'WS', 'AT', 'LWR', 'AP', 'TP', 'SH', 'Lat', 'Lon', 'Day', 'DB'] # all of them
names_new = ['SWR', 'TP', 'Lat', 'Lon', 'NPR'] # change depending on phytoplankton quantity

names_long = ['Downward Short-Wave Radiation Flux', 'Wind Speed', 'Air Temperature', 'Downward Long-Wave Radiation Flux', 'Pressure Reduced to MSL', 'Total precipitation',
    'Specific humidity', 'Latitude', 'Longitude', 'Day of the year', 'Diatom biomass'] # all of them
names_long = ['Downward Short-Wave Radiation Flux', 'Total precipitation', 'Latitude', 'Longitude', 'Nanoflagellate production rate'] # change depending on phytoplankton quantity

units = ['W m-2', 'm s-1', 'K', 'W m-2', 'Pa', 'Kg m-2 s-1', 'kg kg-1', 'degrees', 'degrees', '#', 'mmol N m-2'] # all of them
units = ['W m-2', 'Kg m-2 s-1', 'degrees', 'degrees', 's-1'] # change depending on phytoplankton quantity

levels = ['Surface', '10 m above surface', '2 m above surface', 'Surface', 'Mean sea level', 'Surface', '2 m above surface', '-', '-', '-', '0-100 m depth integrated'] # all of them
levels = ['Surface', 'Surface', '-', '-', '-', '0-100 m depth integrated'] # change depending on phytoplankton quantity

indx = []
indx.append(vars.index('Summation_of_solar_radiation'))
indx.append(vars.index('Mean_precipitation'))

indx.append(vars.index('Latitude'))
indx.append(vars.index('Longitude'))

indx.append(vars.index('Flagellate_Production_Rate'))

coords = dict(time_counter=file.time_counter, y=file.y, x=file.x)

# %%
ds = xr.Dataset()

for i in range(0, len(names_new)):

    temp = xr.DataArray(file[vars[indx[i]]], coords, dims=('time_counter','y','x'), name=names_new[i], attrs = dict(long_name=names_long[i], levels=levels[i], units=units[i]))
    
    ds[names_new[i]]=temp

ds.attrs['Name'] = 'Ilias Bougoudis'
ds.attrs['Institution'] = 'The University of British Columbia'
ds.attrs['Department'] = 'Earth, Ocean and Atmospheric Sciences'
ds.attrs['E-mail'] = 'salishsea@eoas.ubc.ca'
ds.attrs['Atmospheric drivers source'] = 'The Pan-Canadian High Resolution (2.5 km) Deterministic Prediction System, DOI: https://doi.org/10.1175/WAF-D-16-0035.1, https://open.canada.ca/data/en/dataset/5b401fa0-6c29-57f0-b3d5-749f301d829d'
ds.attrs['Phytoplankton variables source'] = 'SalishSeaCast V202111, DOI: https://dx.doi.org/10.1029/2019JC015766, https://salishsea.eos.ubc.ca/erddap/index.html'
ds.attrs['Git-hub repository'] = 'DOI: https://doi.org/10.5281/zenodo.17180298, https://github.com/SalishSeaCast/MachineLearningPhytoplanktonPaper'
ds.attrs['Publication'] = 'Using Machine Learning to Predict Phytoplankton Blooms in the Salish Sea'

# %%
ds

# %%
comp = dict(zlib=True, complevel=9)
for var in ds.data_vars: 
    ds[var].encoding.update(comp)
ds.to_netcdf('/data/ibougoudis/MOAD/files/seasonalities2.nc') # change depending on phytoplankton quantity
ds.close()
