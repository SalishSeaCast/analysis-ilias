# %% [markdown]
# First dummy plot

# %%
# Importing

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import salishsea_tools.viz_tools as sa_vi

# %%
# Dataset preparation

ds = xr.open_dataset('/data/ibougoudis/MOAD/SalishSeaCast_1m_ptrc_T_20221201_20221231.nc')
ds
# # open the mesh mask
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask202108.nc')


fig, ax = plt.subplots(1, 1, figsize=(5, 9))

diatoms_m = np.ma.masked_array(ds.diatoms[0,0],mask = 1 - mesh.tmask[0,0])
ax.pcolormesh(diatoms_m)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 9))

ds.diatoms[0,0].where(ds.diatoms[0,0]>0).plot(ax=ax)
cmap = cm.haline
cmap.set_bad('gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data/ibougoudis/MOAD/analysis-ilias/test.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fig, ax = plt.subplots(1, 1, figsize=(5, 9))
#       <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> ds.diatoms[0,0].where(ds.diatoms[0,0]>0).plot(ax=ax)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> cmap = cm.haline
#       <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> cmap.set_bad('gray')
#
# NameError: name 'cm' is not defined
