# %% [markdown]
# First dummy plot

# %%
# Importing

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import salishsea_tools.viz_tools as sa_vi

# %%
# Dataset preparation

ds = xr.open_dataset('/data/ibougoudis/MOAD/SalishSeaCast_1m_ptrc_T_20221201_20221231.nc')
depth = ds['depth']
dia = ds['diatoms']
dia
# Out:
# <xarray.DataArray 'diatoms' (time: 1, depth: 40, gridY: 898, gridX: 398)>
# [14296160 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2022-12-15T12:00:00
#   * depth    (depth) float32 0.5 1.5 2.5 3.5 4.5 ... 360.7 387.6 414.5 441.5
#   * gridY    (gridY) int64 0 1 2 3 4 5 6 7 8 ... 890 891 892 893 894 895 896 897
#   * gridX    (gridX) int64 0 1 2 3 4 5 6 7 8 ... 390 391 392 393 394 395 396 397
# Attributes:
#     standard_name:  mole_concentration_of_diatoms_expressed_as_nitrogen_in_se...
#     long_name:      Diatoms Concentration
#     units:          mmol m-3

# %%
# Plotting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/ibougoudis/MOAD/analysis-ilias/test.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Plotting
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bchar/data/ibougoudis/MOAD/analysis-ilias/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sa_vi2.create_figure()
#
# TypeError: create_figure() missing 2 required positional arguments: 'ax' and 'DATA'
